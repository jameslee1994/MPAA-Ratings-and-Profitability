# %% [markdown]
# <a href="https://colab.research.google.com/github/jameslee1994/Final-Project/blob/main/Final_Project_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
For this project we will be importing data from 2 different data sets and using them to explore energy trends by country over the past 4 decades, particularly in the US vs China:

  * df_gdp - This data set includes per-capita electricity generation and GDP by country, from 1985-2024 (measured in US dollars).
  This data is from the Our World In Data website. Metadata related to this data can be found here: https://ourworldindata.org/grapher/per-capita-electricity-generation-vs-gdp-per-capita?metadata.
"""
# Out:
# '\nFor this project we will be importing data from 2 different data sets and using them to :\n\n  * df_energy - This data set includes per-capita electricity generation by country, from 1985-2024 (measured in kilowatt-hours).\n  This data is from the Our World In Data website. Metadata related to this data can be found here: https://ourworldindata.org/grapher/per-capita-electricity-generation?metadata.\n\n  * df_gdp - This data set includes per-capita GDP by country, from 1985-2024 (measured in US dollars).\n  This data is from the Our World In Data website. Metadata related to this data can be found here: https://ourworldindata.org/grapher/per-capita-electricity-generation-vs-gdp-per-capita?metadata.\n'

# %%
"""
Data Cleaning: Data appears to be of good quality and internally consistent. There are some rows that don't have data that will need to be looked at. There is significant documentation and metadata explaining the columns and data format.
"""

# %%
import pandas as pd
import requests

# %%
# Import the df_gpd dataset
df_gdp = pd.read_csv("https://ourworldindata.org/grapher/per-capita-electricity-generation-vs-gdp-per-capita.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# %%
# Preview the df_gdp dataset.
df_gdp.head()
# Out:
#         Entity Code  Year  per_capita_total_generation__kwh  \
# 0  Afghanistan  AFG  2000                         23.844612
# 1  Afghanistan  AFG  2001                         34.016453
# 2  Afghanistan  AFG  2002                         33.211520
# 3  Afghanistan  AFG  2003                         40.029820
# 4  Afghanistan  AFG  2004                         33.530476
#
#    ny_gdp_pcap_pp_kd owid_region
# 0          1617.8264         NaN
# 1          1454.1108         NaN
# 2          1774.3087         NaN
# 3          1815.9282         NaN
# 4          1776.9182         NaN

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8549 entries, 0 to 8548
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Entity                            8549 non-null   object
#  1   Code                              7860 non-null   object
#  2   Year                              8549 non-null   int64
#  3   per_capita_total_generation__kwh  6831 non-null   float64
#  4   ny_gdp_pcap_pp_kd                 7236 non-null   float64
#  5   owid_region                       272 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 400.9+ KB
